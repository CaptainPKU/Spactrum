# %%
# version 3.0 measurement results
import numpy as np
import matplotlib.pyplot as plt

FWHM_Hb = []
R_FeII = []
EW_OIII = []
Log_EW_OIII = []
EW_Hb = []

with open('resultsdataV3.txt', 'r') as file:
    # 跳过第一行
    next(file) 
    # 逐行读取文件
    for line in file:
        # 将每行数据按空格或逗号等分隔符分割成列表
        data = line.strip().split()
        # 检查数据列数是否足够
        if len(data) >= 5:
            # 将每列数据分别添加到对应的列表中
            FWHM_Hb.append(float(data[0]))
            R_FeII.append(float(data[1]))
            EW_OIII.append(float(data[2]))
            Log_EW_OIII.append(float(data[3]))
            EW_Hb.append(float(data[4]))

print("Column 1:", FWHM_Hb)
print("Column 2:", R_FeII)
print("Column 3:", EW_OIII)
print("Column 4:", Log_EW_OIII)
print("Column 5:", EW_Hb)

column1 = np.array(FWHM_Hb)
column2 = np.array(R_FeII)
column3 = np.array(EW_OIII)
column4 = np.array(Log_EW_OIII)
column5 = np.array(EW_Hb)

# 创建二维图像
plt.figure(figsize=(6, 6))
# 绘制散点图
sc = plt.scatter(column2, column1, c=column4, cmap='rainbow')
# 添加颜色条
colorbar = plt.colorbar(sc, orientation='horizontal', pad=0.1, location='top')
colorbar.set_label('log(EW_OIII(angstrom))')
# 设置轴标签
plt.xlabel('R_FeII')
plt.ylabel('FWHM_Hb(km/s)')
plt.ylim(0, 10000)
plt.xlim(0, 3)
# 显示图像
plt.show()

EW_FeII=np.array(R_FeII)*np.array(EW_Hb)
print(EW_FeII)
# Out:
# Column 1: [5021.0261, 5550.2285, 4591.7452, 2377.5566, 5853.7995, 6651.4438, 5057.9408, 3131.598, 5206.0499, 3936.4978, 3132.5993, 8201.5903, 2903.5031, 3075.9992, 3171.4773, 5828.6736, 2415.3467]
# Column 2: [0.48153149, 0.0, 0.30863826, 0.4790015, 0.31483534, 0.52625137, 0.50787708, 0.17473879, 0.17082152, 0.36875751, 0.23756935, 0.1843096, 1.4936758, 0.55783701, 0.52348908, 0.35874223, 0.65670866]
# Column 3: [8.6136797, 32.690956, 78.345801, 47.523002, 68.054358, 9.7174749, 32.208447, 58.852204, 37.393953, 19.48684, 11.284769, 40.823271, 0.92627596, 7.3469332, 37.770556, 26.46409, 8.0685703]
# Column 4: [0.93518872, 1.5144276, 1.8940157, 1.6769039, 1.8328559, 0.98755343, 1.5079698, 1.7697627, 1.5728014, 1.2897414, 1.0524927, 1.6109078, -0.033259607, 0.86610609, 1.5771534, 1.422657, 0.90679659]
# Column 5: [58.355732, 26.702354, 107.57384, 82.891721, 69.489444, 99.739873, 82.259895, 117.18986, 120.04578, 98.061558, 86.352913, 89.959741, 46.729484, 82.103321, 49.958161, 89.594044, 59.17097]
# [28.10012258  0.         33.2014028  39.7052587  21.87773273 52.48824481
#  41.77791527 20.47761434 20.50640261 36.16093595 20.51480541 16.58044388
#  69.7986994  45.8002711  26.15255174 32.14116714 38.85808842]

# %%
# our sample data involved in Boroson&Green1992
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def read_data(file_path):
    # Define column names
    columns = ["Name", "EW_Hb", "EW_5007", "EW_FeII", "FWHM_Hb", "R_FeII"]
    
    # Initialize an empty list to store the data
    data = []
    
    # Open the file and read line by line
    with open(file_path, 'r', encoding='utf-8') as file:
        # Skip the first line as it contains column names
        next(file)
        
        for line in file:
            # Split the line into parts
            parts = line.split()
            
            # If the line has less than 6 parts, it means some data is missing
            if len(parts) < 6:
                # Fill missing data with -100
                parts.extend([-100] * (6 - len(parts)))
            
            # Convert numerical parts to float, keep the name as string
            parts = [parts[0]] + [float(x) for x in parts[1:]]
            
            # Append the parts to the data list
            data.append(parts)
    
    # Create a DataFrame from the data
    df = pd.DataFrame(data, columns=columns)
    
    # Extract each column into a separate list
    name_list = df["Name"].tolist()
    ew_hb_list = df["EW_Hb"].tolist()
    ew_5007_list = df["EW_5007"].tolist()
    ew_feii_list = df["EW_FeII"].tolist()
    fwhm_hb_list = df["FWHM_Hb"].tolist()
    r_feii_list = df["R_FeII"].tolist()
    
    return name_list, ew_hb_list, ew_5007_list, ew_feii_list, fwhm_hb_list, r_feii_list
def plot_data(r_feii_list, fwhm_hb_list, ew_5007_list):
    # Filter out -100 values
    filtered_r_feii = []
    filtered_fwhm_hb = []
    filtered_ew_5007 = []
    
    for r, fwhm, ew in zip(r_feii_list, fwhm_hb_list, ew_5007_list):
        if r != -100 and fwhm != -100 and ew != -100:
            filtered_r_feii.append(r)
            filtered_fwhm_hb.append(fwhm)
            filtered_ew_5007.append(ew)
    
    # Convert EW_5007 to log scale
    log_ew_5007 = np.log10(filtered_ew_5007)
    
    # Create the scatter plot
  
    sc=plt.scatter(filtered_r_feii, filtered_fwhm_hb, c=log_ew_5007, cmap='rainbow')
    #plt.colorbar(label='log10(EW_5007)')
    plt.colorbar(sc, orientation='horizontal', pad=0.1, location='top')
    plt.xlabel('R_FeII')
    plt.ylabel('FWHM_Hb')
    plt.title('Scatter plot of FWHM_Hb vs R_FeII with color as log10(EW_5007)')
    plt.ylim(0, 10000)
    plt.xlim(0, 3)
    plt.show()

file_path = 'c:/Users/liao/PycharmProjects/pythonProject1/AAA.Graduate work/MeasureV3/resultsV3/data_Boroson1992.txt'
name_list, ew_hb_list, ew_5007_list, ew_feii_list, fwhm_hb_list, r_feii_list = read_data(file_path)
print(name_list)
print(ew_hb_list)
print(ew_5007_list)
print(ew_feii_list)
print(fwhm_hb_list)
print(r_feii_list)


plot_data(r_feii_list, fwhm_hb_list, ew_5007_list)
# Out:
# ['3C273(Pg1226+023/1990)', '3C351(pg1704+608/1990)', '4C+34.47(B2_1721+34无)', 'ir07546(MS0754.6+3928无)', 'MRK290(pg1534+580/1990)', 'MRK304(pg2214+139/1990)', 'MRK506(无)', 'MRK509(无)', 'pg0052/1990', 'pg0947/1991', 'pg0953/1990', 'pg1100/1990', 'pg1259/1991', 'pg1322/1990', 'pg1351/1990', 'pg2349(无)', 'ton951(pg0844+349/1990)', -100]
# [113.0, 28.0, -100.0, -100.0, 97.0, 107.0, -100.0, -100.0, 87.0, 110.0, 156.0, 90.0, 61.0, 77.0, 58.0, -100.0, 76.0, -100.0]
# [5.0, 27.0, -100.0, -100.0, 79.0, 9.0, -100.0, -100.0, 30.0, 15.0, 18.0, 41.0, 0.0, 8.0, 31.0, -100.0, 8.0, -100.0]
# [64.0, 0.0, -100.0, -100.0, 26.0, 34.0, -100.0, -100.0, 20.0, 25.0, 39.0, 19.0, 81.0, 45.0, 14.0, -100.0, 68.0, -100.0]
# [3520.0, 6560.0, -100.0, -100.0, 5340.0, 4550.0, -100.0, -100.0, 5200.0, 4830.0, 3130.0, 6160.0, 3390.0, 2790.0, 5660.0, -100.0, 2420.0, -100.0]
# [0.57, 0.0, -100.0, -100.0, 0.27, 0.32, -100.0, -100.0, 0.23, 0.23, 0.25, 0.21, 1.27, 0.59, 0.24, -100.0, 0.89, -100.0]
# C:\Users\liao\AppData\Local\Temp\ipykernel_6488\3724359353.py:58: RuntimeWarning: divide by zero encountered in log10
#   log_ew_5007 = np.log10(filtered_ew_5007)

# %%
import matplotlib.pyplot as plt

def plot_comparison(x_list, y_list, x_label, y_label):
    # Filter out -100 values
    filtered_x = []
    filtered_y = []
    
    for x, y in zip(x_list, y_list):
        if x != -100 and y != -100:
            filtered_x.append(x)
            filtered_y.append(y)
    
    # Create the scatter plot
    plt.scatter(filtered_x, filtered_y, c='blue')
    plt.plot([min(filtered_x), max(filtered_x)], [min(filtered_x), max(filtered_x)], 'r--')  # y=x line
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f'Scatter plot of {y_label} vs {x_label}')
    plt.show()



# Plot comparisons 横轴全是Boroson1992的数据，纵轴是我们的数据
plot_comparison(ew_5007_list, EW_OIII, 'ew_5007_list', 'EW_OIII')
plot_comparison(fwhm_hb_list, FWHM_Hb, 'fwhm_hb_list', 'FWHM_Hb')
plot_comparison(r_feii_list, R_FeII, 'r_feii_list', 'R_FeII')
plot_comparison(ew_hb_list, EW_Hb, 'ew_hb_list', 'EW_Hb')
plot_comparison(ew_feii_list, EW_FeII, 'ew_feii_list', 'EW_FeII')
